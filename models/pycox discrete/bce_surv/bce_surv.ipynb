# %%
import pandas as pd
df = pd.read_pickle("../merged_data.pkl")
df.head()
# Out:
#    CompanyNumber    yyyy  mm  DTDmedianFin  DTDmedianNonFin  dummy297fin  \
# 0          26980  2000.0   5           0.0         2.190874          0.0
# 1          26995  2000.0  12           0.0         1.863172          0.0
# 2          27003  2000.0   6           0.0         2.257787          0.0
# 3          27058  2000.0   3           0.0         2.599548          0.0
# 4          27071  2000.0   4           0.0         2.318686          0.0
#
#                          EventDate EventDate_string            Duration  \
# 0 1970-01-12 01:52:19.200000+00:00          2000 05  4501 days 00:00:00
# 1 1970-01-12 07:00:28.800000+00:00          2000 12  4715 days 00:00:00
# 2 1970-01-12 02:36:57.600000+00:00          2000 06  4532 days 00:00:00
# 3 1970-01-12 00:24:28.800000+00:00          2000 03  4440 days 00:00:00
# 4 1970-01-12 01:09:07.200000+00:00          2000 04  4471 days 00:00:00
#
#                          StartDate  ...  equity_ratio  \
# 0 1970-01-07 13:50:52.800000+00:00  ...      8.653470
# 1 1970-01-07 13:50:52.800000+00:00  ...      5.227711
# 2 1970-01-07 13:50:52.800000+00:00  ...      2.758440
# 3 1970-01-07 13:50:52.800000+00:00  ...      0.977792
# 4 1970-01-07 13:50:52.800000+00:00  ...      0.883145
#
#   financial_leverage_ratio cashflow_to_debt_ratio net_profit_margin  \
# 0                 0.115561               0.353320          0.496181
# 1                 0.191288               0.270503          0.309987
# 2                 0.362524               0.040856          0.553460
# 3                 1.022712               0.154983          0.351704
# 4                 1.132316               0.307483          0.303481
#
#    asset_turnover  receivables_turnover  day_sales_outstanding  \
# 0        0.500283              0.439043               2.277680
# 1        0.252043              5.105960               0.195850
# 2        0.471932              0.027663              42.234378
# 3        1.000000              2.866751               0.348827
# 4        0.541856              1.503662               0.665043
#
#    working_capital_turnover  price_to_earnings  retention_ratio
# 0                  6.329094         -10.552301         5.626957
# 1                -30.840000          98.727273         0.127184
# 2                  1.449149          42.256637        13.899441
# 3                  0.677361          14.625000         5.160377
# 4                  3.567568          17.829861        14.014418
#
# [5 rows x 65 columns]

# %%
# Unnecessary cols
labels_to_drop = [
    'CompanyNumber',
    'EventDate',
    'EventDate_string',
    'StartDate',
    'gvkey',
    'datadate', 
    'yyyy',  
    'mm', 
]
df = df.drop(labels_to_drop, axis=1)
df.head()
# Out:
#    DTDmedianFin  DTDmedianNonFin  dummy297fin            Duration  EventType  \
# 0           0.0         2.190874          0.0  4501 days 00:00:00        0.0
# 1           0.0         1.863172          0.0  4715 days 00:00:00        0.0
# 2           0.0         2.257787          0.0  4532 days 00:00:00        0.0
# 3           0.0         2.599548          0.0  4440 days 00:00:00        0.0
# 4           0.0         2.318686          0.0  4471 days 00:00:00        0.0
#
#       sic        atq        ltq     dlcq  txditcq  ...  equity_ratio  \
# 0  3612.0   1498.445    734.978    2.442     0.00  ...      8.653470
# 1  4513.0  12535.000   8196.000  230.000  1156.00  ...      5.227711
# 2  5411.0   9032.869   8359.571  474.892     0.00  ...      2.758440
# 3  3674.0     14.934      5.776    0.000     0.17  ...      0.977792
# 4  5065.0  44791.000  28595.000  598.000     0.95  ...      0.883145
#
#    financial_leverage_ratio  cashflow_to_debt_ratio  net_profit_margin  \
# 0                  0.115561                0.353320           0.496181
# 1                  0.191288                0.270503           0.309987
# 2                  0.362524                0.040856           0.553460
# 3                  1.022712                0.154983           0.351704
# 4                  1.132316                0.307483           0.303481
#
#    asset_turnover  receivables_turnover  day_sales_outstanding  \
# 0        0.500283              0.439043               2.277680
# 1        0.252043              5.105960               0.195850
# 2        0.471932              0.027663              42.234378
# 3        1.000000              2.866751               0.348827
# 4        0.541856              1.503662               0.665043
#
#    working_capital_turnover  price_to_earnings  retention_ratio
# 0                  6.329094         -10.552301         5.626957
# 1                -30.840000          98.727273         0.127184
# 2                  1.449149          42.256637        13.899441
# 3                  0.677361          14.625000         5.160377
# 4                  3.567568          17.829861        14.014418
#
# [5 rows x 57 columns]

# %%
# Format Event Type col
df = df[df['EventType'] != 2]
df['EventType'] = df['EventType'].apply(lambda x: '1' if x == 1 else '0')
df['EventType'].value_counts()
# Out:
# 0    574747
# 1      4464
# Name: EventType, dtype: int64

# %%
# Format Duration col
df['Duration'] = df['Duration'].astype(str)
df['Duration'] = df['Duration'].str.replace(r'\s', '', regex=True)
df['Duration'] = df['Duration'].str.split('days').str[0]
df['Duration'] = df['Duration'].astype('float64')

# %%
from pycox.models import BCESurv
from pycox.evaluation import EvalSurv
import numpy as np
import torchtuples as tt

# %%
# Split into train,test, validation
df_train = df
df_test = df_train.sample(frac=0.2)
df_train = df_train.drop(df_test.index)
df_val = df_train.sample(frac=0.2)
df_train = df_train.drop(df_val.index)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn_pandas import DataFrameMapper 
og_cols = df_train.columns.tolist()
cols_standardize = [i for i in og_cols if i not in ['Duration', 'EventType']]
cols_leave =[]

standardize = [([col], StandardScaler()) for col in cols_standardize]
leave = [(col, None) for col in cols_leave]

x_mapper = DataFrameMapper(standardize + leave)

# %%
x_train = x_mapper.fit_transform(df_train).astype('float32')
x_val = x_mapper.transform(df_val).astype('float32')
x_test = x_mapper.transform(df_test).astype('float32')

# %%
# Discretize time column
num_durations = 10

labtrans = BCESurv.label_transform(num_durations)

get_target = lambda df: (df['Duration'].values, df['EventType'].values)
y_train = labtrans.fit_transform(*get_target(df_train))
y_val = labtrans.transform(*get_target(df_val))

train = (x_train, y_train)
val = (x_val, y_val)

# We don't need to transform the test labels
durations_test, events_test = get_target(df_test)

# %%
in_features = x_train.shape[1]
num_nodes = [32, 32]
out_features = labtrans.out_features
batch_norm = True
dropout = 0.1

net = tt.practical.MLPVanilla(in_features, num_nodes, out_features, batch_norm, dropout)
model = BCESurv(net, tt.optim.Adam, duration_index=labtrans.cuts)

# %%
batch_size = 256
lr_finder = model.lr_finder(x_train, y_train, batch_size, tolerance=3)
_ = lr_finder.plot()

# %%
lr_finder.get_best_lr()
# Out:
# 0.08902150854450441

# %%
model.optimizer.set_lr(0.01)

# %%
epochs = 100
callbacks = [tt.callbacks.EarlyStopping()]
log = model.fit(x_train, y_train, batch_size, epochs, callbacks, val_data=val)
# Out:
# 0:	[2s / 2s],		train_loss: 0.3195,	val_loss: 0.3143
# 1:	[2s / 5s],		train_loss: 0.3095,	val_loss: 0.3076
# 2:	[2s / 7s],		train_loss: 0.3071,	val_loss: 0.3061
# 3:	[2s / 10s],		train_loss: 0.3052,	val_loss: 0.3038
# 4:	[2s / 12s],		train_loss: 0.3039,	val_loss: 0.3017
# 5:	[2s / 14s],		train_loss: 0.3031,	val_loss: 0.3018
# 6:	[2s / 17s],		train_loss: 0.3026,	val_loss: 0.3023
# 7:	[2s / 19s],		train_loss: 0.3020,	val_loss: 0.3006
# 8:	[2s / 22s],		train_loss: 0.3016,	val_loss: 0.3013
# 9:	[2s / 25s],		train_loss: 0.3013,	val_loss: 0.3018
# 10:	[2s / 27s],		train_loss: 0.3011,	val_loss: 0.3014
# 11:	[2s / 30s],		train_loss: 0.3007,	val_loss: 0.2993
# 12:	[2s / 33s],		train_loss: 0.3006,	val_loss: 0.2995
# 13:	[2s / 35s],		train_loss: 0.3002,	val_loss: 0.2983
# 14:	[2s / 38s],		train_loss: 0.3000,	val_loss: 0.3005
# 15:	[2s / 40s],		train_loss: 0.3000,	val_loss: 0.3012
# 16:	[2s / 43s],		train_loss: 0.2998,	val_loss: 0.2978
# 17:	[2s / 45s],		train_loss: 0.2996,	val_loss: 0.3000
# 18:	[2s / 48s],		train_loss: 0.2996,	val_loss: 0.2985
# 19:	[2s / 50s],		train_loss: 0.2995,	val_loss: 0.3000
# 20:	[2s / 53s],		train_loss: 0.2992,	val_loss: 0.2997
# 21:	[2s / 55s],		train_loss: 0.2995,	val_loss: 0.2993
# 22:	[2s / 58s],		train_loss: 0.2991,	val_loss: 0.2980
# 23:	[2s / 1m:0s],		train_loss: 0.2990,	val_loss: 0.3001
# 24:	[2s / 1m:2s],		train_loss: 0.2988,	val_loss: 0.2983
# 25:	[2s / 1m:5s],		train_loss: 0.2989,	val_loss: 0.2990
# 26:	[2s / 1m:7s],		train_loss: 0.2986,	val_loss: 0.2968
# 27:	[2s / 1m:10s],		train_loss: 0.2986,	val_loss: 0.2980
# 28:	[2s / 1m:12s],		train_loss: 0.2985,	val_loss: 0.2989
# 29:	[2s / 1m:15s],		train_loss: 0.2983,	val_loss: 0.2972
# 30:	[2s / 1m:17s],		train_loss: 0.2984,	val_loss: 0.2999
# 31:	[2s / 1m:20s],		train_loss: 0.2983,	val_loss: 0.2971
# 32:	[2s / 1m:22s],		train_loss: 0.2983,	val_loss: 0.2958
# 33:	[2s / 1m:25s],		train_loss: 0.2984,	val_loss: 0.2978
# 34:	[2s / 1m:27s],		train_loss: 0.2984,	val_loss: 0.2982
# 35:	[2s / 1m:29s],		train_loss: 0.2982,	val_loss: 0.2963
# 36:	[2s / 1m:32s],		train_loss: 0.2978,	val_loss: 0.2983
# 37:	[2s / 1m:34s],		train_loss: 0.2981,	val_loss: 0.2975
# 38:	[2s / 1m:37s],		train_loss: 0.2979,	val_loss: 0.2972
# 39:	[2s / 1m:39s],		train_loss: 0.2980,	val_loss: 0.2972
# 40:	[2s / 1m:42s],		train_loss: 0.2978,	val_loss: 0.2967
# 41:	[2s / 1m:44s],		train_loss: 0.2981,	val_loss: 0.2981
# 42:	[2s / 1m:47s],		train_loss: 0.2980,	val_loss: 0.2988

# %%
_ = log.plot()

# %%
import matplotlib.pyplot as plt
surv = model.predict_surv_df(x_test)
surv.iloc[:, :5].plot(drawstyle='steps-post')
plt.ylabel('S(t | x)')
_ = plt.xlabel('Time')

# %%
surv = model.interpolate(10).predict_surv_df(x_test)

# %%
surv.iloc[:, :5].plot(drawstyle='steps-post')
plt.ylabel('S(t | x)')
_ = plt.xlabel('Time')

# %%
ev = EvalSurv(surv, durations_test, events_test.astype(int), censor_surv='km')
# Out:
# /Users/ryantan/Documents/github/Capstone/venv/lib/python3.9/site-packages/pycox/utils.py:57: UserWarning: start_duration 0 is larger than minimum duration -30.0. If intentional, consider changing start_duration when calling kaplan_meier.
#   warnings.warn(f"start_duration {start_duration} is larger than minimum duration {durations.min()}. "

# %%
ev.concordance_td('antolini')
# Out:
# 0.7317383306797476

# %%
time_grid = np.linspace(durations_test.min(), durations_test.max(), 100)
ev.brier_score(time_grid).plot()
plt.ylabel('Brier score')
_ = plt.xlabel('Time')

# %%
ev.integrated_brier_score(time_grid)
# Out:
# 0.28803784657082665

# %%
ev.integrated_nbll(time_grid)
# Out:
# 0.8640565373735972
