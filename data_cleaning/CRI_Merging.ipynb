# %%
import pandas as pd

X = pd.read_csv('X_NorthAmerica.csv')
X
# Out:
#               CompNo    yyyy  mm   StkIndx     STInt  dtdlevel  dtdtrend  \
# 0         15984000.0  1999.0   3  0.167570  0.006248       NaN       NaN
# 1         15984000.0  1999.0   4  0.200972  0.006487       NaN       NaN
# 2         15984000.0  1999.0   5  0.186079  0.006896       NaN       NaN
# 3         15984000.0  1999.0   6  0.210673  0.007457       NaN       NaN
# 4         15984000.0  1999.0   7  0.162536  0.007322  4.190356       0.0
# ...              ...     ...  ..       ...       ...       ...       ...
# 2753072  212037000.0  2023.0   7  0.015960 -0.010290       NaN       NaN
# 2753073  212083000.0  2023.0   6  0.038825 -0.010290       NaN       NaN
# 2753074  212083000.0  2023.0   7  0.015960 -0.010290       NaN       NaN
# 2753075  212122000.0  2023.0   7  0.015960 -0.010290       NaN       NaN
# 2753076  212139000.0  2023.0   7  0.015960 -0.010290       NaN       NaN
#
#          liqnonfinlevel  liqnonfintrend  ni2talevel  ni2tatrend  sizelevel  \
# 0                   NaN             NaN         NaN         NaN   1.027931
# 1                   NaN             NaN         NaN         NaN   1.351854
# 2                   NaN             NaN         NaN         NaN   1.358506
# 3              0.447325             0.0     0.00932         0.0   1.362518
# 4              0.447325             0.0     0.00932         0.0   1.336588
# ...                 ...             ...         ...         ...        ...
# 2753072             NaN             NaN         NaN         NaN  -2.751389
# 2753073        0.000000             0.0         NaN         NaN   0.048190
# 2753074        0.000000             0.0         NaN         NaN  -0.675007
# 2753075             NaN             NaN         NaN         NaN  -2.258285
# 2753076             NaN             NaN         NaN         NaN        NaN
#
#          sizetrend       m2b     sigma  liqfinlevel  lqfintrend  DTDmedianFin  \
# 0         0.000000       NaN       NaN          0.0         0.0      0.000000
# 1         0.323923       NaN       NaN          0.0         0.0      0.000000
# 2         0.013304       NaN  0.274280          0.0         0.0      0.000000
# 3         0.012036  5.082778  0.276896          0.0         0.0      0.000000
# 4        -0.103719  4.504762  0.259755          0.0         0.0      0.000000
# ...            ...       ...       ...          ...         ...           ...
# 2753072   0.000000       NaN       NaN          0.0         0.0      0.000000
# 2753073   0.000000       NaN       NaN          NaN         NaN      3.405230
# 2753074  -0.723197       NaN       NaN          NaN         NaN      3.453191
# 2753075   0.000000       NaN       NaN          0.0         0.0      0.000000
# 2753076        NaN       NaN       NaN          0.0         0.0      0.000000
#
#          DTDmedianNonFin  dummy297fin
# 0               2.324205            0
# 1               2.373554            0
# 2               2.401488            0
# 3               2.455890            0
# 4               2.455596            0
# ...                  ...          ...
# 2753072         2.087496            0
# 2753073         0.000000            1
# 2753074         0.000000            1
# 2753075         2.087496            0
# 2753076         2.087496            0
#
# [2753077 rows x 20 columns]

# %%
## preprocess the X dataset

df_X = X.copy()
df_X['yyyy'] = df_X['yyyy'].astype(int)
df_X['mm'] = df_X['mm'].astype(str)

for index, row in df_X.iterrows():
    if len(row['mm']) == 1:  
        df_X.at[index, 'EventDate'] = str(row['yyyy']) + '0' + row['mm']
    else:
        df_X.at[index, 'EventDate'] = str(row['yyyy']) + row['mm']

    df_X.at[index, 'CompNo'] = row['CompNo']/1000
df_X['CompNo'] = df_X['CompNo'].astype(int)

# Convert the "EventDate" column to datetime format
df_X['EventDate'] = pd.to_datetime(df_X['EventDate'], format='%Y%m')

# # Format the "EventDate" column to show year and month (yyyy mm)
df_X['EventDate_string'] = df_X['EventDate'].dt.strftime('%Y %m')

# Rename the "CompNo" column to "CompanyNumber"
df_X = df_X.rename(columns={'CompNo': 'CompanyNumber'})
df_X.head()
# Out:
# C:\Users\shiho\AppData\Local\Temp\ipykernel_3952\2285662045.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '199903' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_X.at[index, 'EventDate'] = str(row['yyyy']) + '0' + row['mm']
#    CompanyNumber  yyyy mm   StkIndx     STInt  dtdlevel  dtdtrend  \
# 0          15984  1999  3  0.167570  0.006248       NaN       NaN
# 1          15984  1999  4  0.200972  0.006487       NaN       NaN
# 2          15984  1999  5  0.186079  0.006896       NaN       NaN
# 3          15984  1999  6  0.210673  0.007457       NaN       NaN
# 4          15984  1999  7  0.162536  0.007322  4.190356       0.0
#
#    liqnonfinlevel  liqnonfintrend  ni2talevel  ...  sizetrend       m2b  \
# 0             NaN             NaN         NaN  ...   0.000000       NaN
# 1             NaN             NaN         NaN  ...   0.323923       NaN
# 2             NaN             NaN         NaN  ...   0.013304       NaN
# 3        0.447325             0.0     0.00932  ...   0.012036  5.082778
# 4        0.447325             0.0     0.00932  ...  -0.103719  4.504762
#
#       sigma  liqfinlevel  lqfintrend  DTDmedianFin  DTDmedianNonFin  \
# 0       NaN          0.0         0.0           0.0         2.324205
# 1       NaN          0.0         0.0           0.0         2.373554
# 2  0.274280          0.0         0.0           0.0         2.401488
# 3  0.276896          0.0         0.0           0.0         2.455890
# 4  0.259755          0.0         0.0           0.0         2.455596
#
#    dummy297fin  EventDate  EventDate_string
# 0            0 1999-03-01           1999 03
# 1            0 1999-04-01           1999 04
# 2            0 1999-05-01           1999 05
# 3            0 1999-06-01           1999 06
# 4            0 1999-07-01           1999 07
#
# [5 rows x 22 columns]

# %%
import pandas as pd

InterestRates = pd.read_csv('InterestRates(Annual).csv')

InterestRates = InterestRates.drop(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'Flag Codes'], axis=1)
InterestRates.rename(columns={'TIME': 'yyyy'}, inplace=True)
InterestRates.head()

df_X = df_X.merge(InterestRates, on='yyyy', how='left')
df_X.head()
# Out:
#    CompanyNumber  yyyy mm   StkIndx     STInt  dtdlevel  dtdtrend  \
# 0          15984  1999  3  0.167570  0.006248       NaN       NaN
# 1          15984  1999  4  0.200972  0.006487       NaN       NaN
# 2          15984  1999  5  0.186079  0.006896       NaN       NaN
# 3          15984  1999  6  0.210673  0.007457       NaN       NaN
# 4          15984  1999  7  0.162536  0.007322  4.190356       0.0
#
#    liqnonfinlevel  liqnonfintrend  ni2talevel  ...       m2b     sigma  \
# 0             NaN             NaN         NaN  ...       NaN       NaN
# 1             NaN             NaN         NaN  ...       NaN       NaN
# 2             NaN             NaN         NaN  ...       NaN  0.274280
# 3        0.447325             0.0     0.00932  ...  5.082778  0.276896
# 4        0.447325             0.0     0.00932  ...  4.504762  0.259755
#
#    liqfinlevel  lqfintrend  DTDmedianFin  DTDmedianNonFin  dummy297fin  \
# 0          0.0         0.0           0.0         2.324205            0
# 1          0.0         0.0           0.0         2.373554            0
# 2          0.0         0.0           0.0         2.401488            0
# 3          0.0         0.0           0.0         2.455890            0
# 4          0.0         0.0           0.0         2.455596            0
#
#    EventDate  EventDate_string     Value
# 0 1999-03-01           1999 03  5.636667
# 1 1999-04-01           1999 04  5.636667
# 2 1999-05-01           1999 05  5.636667
# 3 1999-06-01           1999 06  5.636667
# 4 1999-07-01           1999 07  5.636667
#
# [5 rows x 23 columns]

# %%
import pandas as pd
df_Y = pd.read_csv('Y_NorthAmerica.csv')

df_Y['EventDate'] = pd.to_datetime(df_Y['EventDate'], format='%Y%m%d')
df_Y['Time_Begin'] = pd.to_datetime(df_Y['Time_Begin'], format='%Y%m%d')

# # Format the "EventDate" column to show year and month (yyyy mm)
df_Y['EventDate_string'] = df_Y['EventDate'].dt.strftime('%Y %m')
# # Format the "EventDate" column to show year and month (yyyy mm)
# df_Y['EventDate'] = df_Y['EventDate'].dt.strftime('%Y %m')

# # Format the "EventDate" column to show year and month (yyyy mm)
# df_Y['Time_Begin'] = df_Y['Time_Begin'].dt.strftime('%Y %m')

df_Y = df_Y.rename(columns={'CompNo': 'CompanyNumber', 'Event_type': 'EventType','Time_Begin': 'StartDate'})
df_Y = df_Y.drop(['Sector_Number', 'Exchange'], axis=1)

df_Y.head()
# df_Y.dtypes
# Out:
#    CompanyNumber  EventDate  EventType  StartDate EventDate_string
# 0       15984000 2008-10-17          1 1999-03-15          2008 10
# 1       18729000 2023-07-31          0 2021-01-28          2023 07
# 2       22043000 2023-07-31          0 2015-08-26          2023 07
# 3       22043001 2013-04-30          2 2004-09-27          2013 04
# 4       26978000 2023-07-31          0 2009-05-05          2023 07

# %%
for index, row in df_Y.iterrows():
    df_Y.at[index, 'CompanyNumber'] = row['CompanyNumber']/1000
df_Y['CompanyNumber'] = df_Y['CompanyNumber'].astype(int)

key_column = df_Y['CompanyNumber']
value_column = df_Y['StartDate']

# Create a dictionary from the two columns
comp_start_date = dict(zip(key_column, value_column))
# Out:
# C:\Users\shiho\AppData\Local\Temp\ipykernel_3952\759584361.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '22043.001' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_Y.at[index, 'CompanyNumber'] = row['CompanyNumber']/1000

# %%
import pandas as pd
from datetime import datetime, timedelta

df_Y_new = pd.DataFrame()

# # Format the "EventDate" column to show year and month (yyyy mm)
# df_Y['EventDate'] = df_Y['EventDate'].dt.strftime('%Y %m')

# Sort the DataFrame by CompanyNumber and EventDate
df_Y.sort_values(by=['CompanyNumber', 'EventDate'], inplace=True)

# Function to check if event type 1 occurred n months ago for the same comp number
df_Y_new  # Declare df_Y_new as a global variable

for index, row in df_Y.iterrows():  
    comp_number = row['CompanyNumber']
    event_date = row['EventDate']

    if row['EventType'] == 1:
        for i in range(1, 13):  # Check for the past 12 months
            # Convert event_date to datetime format
            event_date = pd.to_datetime(event_date, format='%Y %m')

            # Calculate the date i months ago from the current event date
            i_months_ago = event_date - pd.DateOffset(months=i)

            # Check if the combination of CompanyNumber and i_months_ago is not in the original df_Y
            if not ((df_Y['CompanyNumber'] == comp_number) & (df_Y['EventDate_string'] == i_months_ago.strftime('%Y %m'))).any():
                
                # If not present, add a new row to df_Y_new
                new_row = {'EventDate_string': i_months_ago.strftime('%Y %m'), 'CompanyNumber': comp_number, 'EventType': 1, 'StartDate':row['StartDate']}
                new_df = pd.DataFrame([new_row])
                df_Y_new = pd.concat([df_Y_new, new_df], ignore_index=True)







# new_df

# %%
new_df = pd.concat([df_Y, df_Y_new], ignore_index=True)
new_df = new_df.drop_duplicates(subset=['EventDate_string', 'CompanyNumber','EventType'], keep='last')
new_df = new_df.drop(['EventDate','StartDate'], axis=1)

# %%
new_df
# Out:
#        CompanyNumber  EventType EventDate_string
# 0               7998          2          2011 07
# 1               7998          2          2019 04
# 2               7998          0          2023 07
# 3              14547          2          2009 06
# 4              14547          2          2016 11
# ...              ...        ...              ...
# 49745         209445          1          2022 06
# 49746         209445          1          2022 05
# 49747         209445          1          2022 04
# 49748         209445          1          2022 03
# 49749         209445          1          2022 02
#
# [49341 rows x 3 columns]

# %%
import numpy as np

for index, row in df_X.iterrows():
    try:
        startDate = comp_start_date[row['CompanyNumber']]
        df_X.at[index, 'StartDate'] = startDate
        df_X.at[index, 'Duration'] = (row['EventDate'] - startDate)
    except KeyError:
        pass

# %%
from pandas_gbq import to_gbq
import json

result = pd.merge(df_X, new_df, on=['CompanyNumber', 'EventDate_string'], how='outer')

# %%
result['EventType'] = result['EventType'].fillna(0)

# %%
result.dtypes
# Out:
# CompanyNumber                 int64
# yyyy                        float64
# mm                           object
# StkIndx                     float64
# STInt                       float64
# dtdlevel                    float64
# dtdtrend                    float64
# liqnonfinlevel              float64
# liqnonfintrend              float64
# ni2talevel                  float64
# ni2tatrend                  float64
# sizelevel                   float64
# sizetrend                   float64
# m2b                         float64
# sigma                       float64
# liqfinlevel                 float64
# lqfintrend                  float64
# DTDmedianFin                float64
# DTDmedianNonFin             float64
# dummy297fin                 float64
# EventDate            datetime64[ns]
# EventDate_string             object
# Value                       float64
# StartDate            datetime64[ns]
# Duration            timedelta64[ns]
# EventType                   float64
# dtype: object

# %%
with open('../token.json', 'r') as token_file:
    token_data = json.load(token_file)
    project_id = token_data.get('project_id', 'default-project-id')

dataset_id = "capstone"
table_id = 'CRI_Merged'

to_gbq(result, destination_table=f'{project_id}.{dataset_id}.{table_id}', project_id=project_id, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# ArrowTypeError                            Traceback (most recent call last)
# Cell In[67], line 8
#       5 dataset_id = "capstone"
#       6 table_id = 'CRI_Merged'
# ----> 8 to_gbq(result, destination_table=f'{project_id}.{dataset_id}.{table_id}', project_id=project_id, if_exists='replace')
#
# File c:\Documents\Capstone\.venv\lib\site-packages\pandas_gbq\gbq.py:1220, in to_gbq(dataframe, destination_table, project_id, chunksize, reauth, if_exists, auth_local_webserver, table_schema, location, progress_bar, credentials, api_method, verbose, private_key, auth_redirect_uri, client_id, client_secret)
#    1215 if dataframe.empty:
#    1216     # Create the table (if needed), but don't try to run a load job with an
#    1217     # empty file. See: https://github.com/pydata/pandas-gbq/issues/237
#    1218     return
# -> 1220 connector.load_data(
#    1221     dataframe,
#    1222     destination_table_ref,
#    1223     write_disposition=write_disposition,
#    1224     chunksize=chunksize,
#    1225     schema=table_schema,
#    1226     progress_bar=progress_bar,
#    1227     api_method=api_method,
#    1228     billing_project=project_id,
#    1229 )
#
# File c:\Documents\Capstone\.venv\lib\site-packages\pandas_gbq\gbq.py:602, in GbqConnector.load_data(self, dataframe, destination_table_ref, write_disposition, chunksize, schema, progress_bar, api_method, billing_project)
#     599 total_rows = len(dataframe)
#     601 try:
# --> 602     chunks = load.load_chunks(
#     603         self.client,
#     604         dataframe,
#     605         destination_table_ref,
#     606         chunksize=chunksize,
#     607         schema=schema,
#     608         location=self.location,
#     609         api_method=api_method,
#     610         write_disposition=write_disposition,
#     611         billing_project=billing_project,
#     612     )
#     613     if progress_bar and tqdm:
#     614         chunks = tqdm.tqdm(chunks)
#
# File c:\Documents\Capstone\.venv\lib\site-packages\pandas_gbq\load.py:243, in load_chunks(client, dataframe, destination_table_ref, chunksize, schema, location, api_method, write_disposition, billing_project)
#     231 def load_chunks(
#     232     client,
#     233     dataframe,
#    (...)
#     240     billing_project: Optional[str] = None,
#     241 ):
#     242     if api_method == "load_parquet":
# --> 243         load_parquet(
#     244             client,
#     245             dataframe,
#     246             destination_table_ref,
#     247             write_disposition,
#     248             location,
#     249             schema,
#     250             billing_project=billing_project,
#     251         )
#     252         # TODO: yield progress depending on result() with timeout
#     253         return [0]
#
# File c:\Documents\Capstone\.venv\lib\site-packages\pandas_gbq\load.py:131, in load_parquet(client, dataframe, destination_table_ref, write_disposition, location, schema, billing_project)
#     128     dataframe = cast_dataframe_for_parquet(dataframe, schema)
#     130 try:
# --> 131     client.load_table_from_dataframe(
#     132         dataframe,
#     133         destination_table_ref,
#     134         job_config=job_config,
#     135         location=location,
#     136         project=billing_project,
#     137     ).result()
#     138 except pyarrow.lib.ArrowInvalid as exc:
#     139     raise exceptions.ConversionError(
#     140         "Could not convert DataFrame to Parquet."
#     141     ) from exc
#
# File c:\Documents\Capstone\.venv\lib\site-packages\google\cloud\bigquery\client.py:2702, in Client.load_table_from_dataframe(self, dataframe, destination, num_retries, job_id, job_id_prefix, location, project, job_config, parquet_compression, timeout)
#    2699     if parquet_compression == "snappy":  # adjust the default value
#    2700         parquet_compression = parquet_compression.upper()
# -> 2702     _pandas_helpers.dataframe_to_parquet(
#    2703         dataframe,
#    2704         new_job_config.schema,
#    2705         tmppath,
#    2706         parquet_compression=parquet_compression,
#    2707         parquet_use_compliant_nested_type=True,
#    2708     )
#    2709 else:
#    2710     dataframe.to_parquet(
#    2711         tmppath,
#    2712         engine="pyarrow",
#    (...)
#    2718         ),
#    2719     )
#
# File c:\Documents\Capstone\.venv\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:719, in dataframe_to_parquet(dataframe, bq_schema, filepath, parquet_compression, parquet_use_compliant_nested_type)
#     712 kwargs = (
#     713     {"use_compliant_nested_type": parquet_use_compliant_nested_type}
#     714     if _helpers.PYARROW_VERSIONS.use_compliant_nested_type
#     715     else {}
#     716 )
#     718 bq_schema = schema._to_schema_fields(bq_schema)
# --> 719 arrow_table = dataframe_to_arrow(dataframe, bq_schema)
#     720 pyarrow.parquet.write_table(
#     721     arrow_table,
#     722     filepath,
#     723     compression=parquet_compression,
#     724     **kwargs,
#     725 )
#
# File c:\Documents\Capstone\.venv\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:662, in dataframe_to_arrow(dataframe, bq_schema)
#     659 for bq_field in bq_schema:
#     660     arrow_names.append(bq_field.name)
#     661     arrow_arrays.append(
# --> 662         bq_to_arrow_array(get_column_or_index(dataframe, bq_field.name), bq_field)
#     663     )
#     664     arrow_fields.append(bq_to_arrow_field(bq_field, arrow_arrays[-1].type))
#     666 if all((field is not None for field in arrow_fields)):
#
# File c:\Documents\Capstone\.venv\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:380, in bq_to_arrow_array(series, bq_field)
#     378 if field_type_upper in schema._STRUCT_TYPES:
#     379     return pyarrow.StructArray.from_pandas(series, type=arrow_type)
# --> 380 return pyarrow.Array.from_pandas(series, type=arrow_type)
#
# File c:\Documents\Capstone\.venv\lib\site-packages\pyarrow\array.pxi:1099, in pyarrow.lib.Array.from_pandas()
#
# File c:\Documents\Capstone\.venv\lib\site-packages\pyarrow\array.pxi:323, in pyarrow.lib.array()
#
# File c:\Documents\Capstone\.venv\lib\site-packages\pyarrow\array.pxi:83, in pyarrow.lib._ndarray_to_array()
#
# File c:\Documents\Capstone\.venv\lib\site-packages\pyarrow\error.pxi:123, in pyarrow.lib.check_status()
#
# ArrowTypeError: Expected a string or bytes dtype, got timedelta64[ns]

# %%
result.isna().sum().sort_values(ascending=False)
# Out:
# dtdlevel            435285
# dtdtrend            435285
# liqnonfinlevel      333045
# liqnonfintrend      333045
# m2b                 323843
# ni2talevel          315340
# ni2tatrend          315340
# sigma               309311
# sizetrend           180306
# sizelevel           180306
# DTDmedianNonFin     146258
# liqfinlevel          84390
# lqfintrend           84390
# StkIndx              66614
# DTDmedianFin         49489
# STInt                36889
# StartDate            19571
# yyyy                 19571
# mm                   19571
# dummy297fin          19571
# EventDate            19571
# Duration             19571
# Value                19571
# CompanyNumber            0
# EventDate_string         0
# EventType                0
# dtype: int64

# %%
count_event_type_1 = len(result[result['EventType'] == 1.0])
count_event_type_1
# Out:
# 16252

# %%
result.shape
result
# Out:
#          CompNo  yyyy mm   StkIndx     STInt  dtdlevel  dtdtrend  \
# 0         15984  1999  3  0.167570  0.006248       NaN       NaN
# 1         15984  1999  4  0.200972  0.006487       NaN       NaN
# 2         15984  1999  5  0.186079  0.006896       NaN       NaN
# 3         15984  1999  6  0.210673  0.007457       NaN       NaN
# 4         15984  1999  7  0.162536  0.007322  4.190356       0.0
# ...         ...   ... ..       ...       ...       ...       ...
# 2753075  212037  2023  7  0.015960 -0.010290       NaN       NaN
# 2753076  212083  2023  6  0.038825 -0.010290       NaN       NaN
# 2753077  212083  2023  7  0.015960 -0.010290       NaN       NaN
# 2753078  212122  2023  7  0.015960 -0.010290       NaN       NaN
# 2753079  212139  2023  7  0.015960 -0.010290       NaN       NaN
#
#          liqnonfinlevel  liqnonfintrend  ni2talevel  ...     sigma  \
# 0                   NaN             NaN         NaN  ...       NaN
# 1                   NaN             NaN         NaN  ...       NaN
# 2                   NaN             NaN         NaN  ...  0.274280
# 3              0.447325             0.0     0.00932  ...  0.276896
# 4              0.447325             0.0     0.00932  ...  0.259755
# ...                 ...             ...         ...  ...       ...
# 2753075             NaN             NaN         NaN  ...       NaN
# 2753076        0.000000             0.0         NaN  ...       NaN
# 2753077        0.000000             0.0         NaN  ...       NaN
# 2753078             NaN             NaN         NaN  ...       NaN
# 2753079             NaN             NaN         NaN  ...       NaN
#
#          liqfinlevel  lqfintrend  DTDmedianFin  DTDmedianNonFin  dummy297fin  \
# 0                0.0         0.0      0.000000         2.324205            0
# 1                0.0         0.0      0.000000         2.373554            0
# 2                0.0         0.0      0.000000         2.401488            0
# 3                0.0         0.0      0.000000         2.455890            0
# 4                0.0         0.0      0.000000         2.455596            0
# ...              ...         ...           ...              ...          ...
# 2753075          0.0         0.0      0.000000         2.087496            0
# 2753076          NaN         NaN      3.405230         0.000000            1
# 2753077          NaN         NaN      3.453191         0.000000            1
# 2753078          0.0         0.0      0.000000         2.087496            0
# 2753079          0.0         0.0      0.000000         2.087496            0
#
#          EventDate  Event_type  Sector_Number  Exchange
# 0           199903         NaN            NaN       NaN
# 1           199904         NaN            NaN       NaN
# 2           199905         NaN            NaN       NaN
# 3           199906         NaN            NaN       NaN
# 4           199907         NaN            NaN       NaN
# ...            ...         ...            ...       ...
# 2753075     202307         0.0           18.0      16.0
# 2753076     202306         NaN            NaN       NaN
# 2753077     202307         0.0           14.0      16.0
# 2753078     202307         0.0           12.0      16.0
# 2753079     202307         0.0           18.0      16.0
#
# [2753080 rows x 24 columns]
